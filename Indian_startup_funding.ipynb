# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_csv(r"C:\temp\dataset\startup_funding.csv")
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %% [markdown]
# df[['Industry Vertical','SubVertical']]

# %%
df.rename(columns={'Sr No':'srno','Date dd/mm/yyyy':'date','Startup Name':'startup_name','Industry Vertical':'industry_vertical',
                 'SubVertical':'subvertical','City  Location':'city','Investors Name':'investor','InvestmentnType':'investment_type',
                  'Amount in USD':'amount','Remarks':'remarks'},inplace=True)

# %%
df.head()
# Out:
#    srno        date                  startup_name    industry_vertical  \
# 0     1  09/01/2020                        BYJU’S               E-Tech
# 1     2  13/01/2020                        Shuttl       Transportation
# 2     3  09/01/2020                     Mamaearth           E-commerce
# 3     4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4     5  02/01/2020                        Fashor  Fashion and Apparel
#
#                              subvertical       city  \
# 0                             E-learning  Bengaluru
# 1              App based shuttle service    Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3                      Online Investment  New Delhi
# 4            Embroiled Clothes For Women     Mumbai
#
#                     investor       investment_type        amount remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# 1  Susquehanna Growth Equity              Series C     80,48,394     NaN
# ...

# %%
df.set_index('srno',inplace=True)

# %%
df.head()
# Out:
#             date                  startup_name    industry_vertical  \
# srno
# 1     09/01/2020                        BYJU’S               E-Tech
# 2     13/01/2020                        Shuttl       Transportation
# 3     09/01/2020                     Mamaearth           E-commerce
# 4     02/01/2020  https://www.wealthbucket.in/              FinTech
# 5     02/01/2020                        Fashor  Fashion and Apparel
#
#                                 subvertical       city  \
# srno
# 1                                E-learning  Bengaluru
# 2                 App based shuttle service    Gurgaon
# 3     Retailer of baby and toddler products  Bengaluru
# 4                         Online Investment  New Delhi
# 5               Embroiled Clothes For Women     Mumbai
#
#                        investor       investment_type        amount remarks
# srno
# 1       Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3044 non-null   object
#  1   startup_name       3044 non-null   object
#  2   industry_vertical  2873 non-null   object
#  3   subvertical        2108 non-null   object
#  4   city               2864 non-null   object
#  5   investor           3020 non-null   object
#  6   investment_type    3040 non-null   object
#  7   amount             2084 non-null   object
#  8   remarks            419 non-null    object
# dtypes: object(9)
# memory usage: 237.8+ KB

# %%
df[['industry_vertical','subvertical']].value_counts()
# Out:
# industry_vertical  subvertical
# Consumer Internet  Food Delivery Platform                              8
# Finance            Online Lending Platform                             6
# eCommerce          Online Pharmacy                                     6
# Consumer Internet  Online Learning Platform                            5
#                    Online lending platform                             5
#                                                                       ..
# eCommerce          Sweets, Dry Fruits & Handicrafts etailer            1
#                    Sweets, Eatables, Handicrafts Online Marketplace    1
#                    Tech Accessories e-tailer                           1
#                    Travel Package Marketplace                          1
# Agriculture        Hybrid Reactor Biodigestor                          1
# Name: count, Length: 1991, dtype: int64

# %%
df[(df['industry_vertical'].notnull()) & (df['subvertical'].isnull())]
# Out:
#             date               startup_name  \
# srno
# 2109  01/12/2015               CollegeDekho
# 2110  01/12/2015  Black White Orange Brands
# 2111  01/12/2015                   Biteclub
# 2112  01/12/2015            Patel Logistics
# 2113  01/12/2015                      Wigzo
# ...          ...                        ...
# 2869  29/04/2015                     Tracxn
# 2870  29/04/2015                       Dazo
# 2871  29/04/2015                   Tradelab
# 2872  29/04/2015                     PiQube
# 2873  29/04/2015            Travel Triangle
#
#                                industry_vertical subvertical       city  \
# srno
# 2109       Online Education Information platform         NaN     Jaipur
# 2110                     Brand Licensing Startup         NaN     Mumbai
# 2111  Gourmet Food Discovery & Delivery platform         NaN    Gurgaon
# 2112         Transportation & Logistics Platform         NaN     Mumbai
# ...

# %%
df[df['industry_vertical'] == 'Online Education Information platform']
# Out:
#             date  startup_name                      industry_vertical  \
# srno
# 2109  01/12/2015  CollegeDekho  Online Education Information platform
#
#      subvertical    city    investor investment_type     amount remarks
# srno
# 2109         NaN  Jaipur  GirnarSoft    Seed Funding  10,00,000     NaN

# %%
df['subvertical'].fillna(df['industry_vertical'],inplace=True)
# Out:
# C:\Users\i527992\AppData\Local\Temp\ipykernel_24788\2599338153.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['subvertical'].fillna(df['industry_vertical'],inplace=True)

# %%
df.head()
# Out:
#             date                  startup_name    industry_vertical  \
# srno
# 1     09/01/2020                        BYJU’S               E-Tech
# 2     13/01/2020                        Shuttl       Transportation
# 3     09/01/2020                     Mamaearth           E-commerce
# 4     02/01/2020  https://www.wealthbucket.in/              FinTech
# 5     02/01/2020                        Fashor  Fashion and Apparel
#
#                                 subvertical       city  \
# srno
# 1                                E-learning  Bengaluru
# 2                 App based shuttle service    Gurgaon
# 3     Retailer of baby and toddler products  Bengaluru
# 4                         Online Investment  New Delhi
# 5               Embroiled Clothes For Women     Mumbai
#
#                        investor       investment_type        amount remarks
# srno
# 1       Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3044 non-null   object
#  1   startup_name       3044 non-null   object
#  2   industry_vertical  2873 non-null   object
#  3   subvertical        2873 non-null   object
#  4   city               2864 non-null   object
#  5   investor           3020 non-null   object
#  6   investment_type    3040 non-null   object
#  7   amount             2084 non-null   object
#  8   remarks            419 non-null    object
# dtypes: object(9)
# memory usage: 237.8+ KB

# %%
df.drop('remarks',axis=1,inplace=True)

# %%
df.dropna(subset=['date','startup_name','industry_vertical','subvertical','city','investor','investment_type','amount'])
# Out:
#             date                  startup_name           industry_vertical  \
# srno
# 1     09/01/2020                        BYJU’S                      E-Tech
# 2     13/01/2020                        Shuttl              Transportation
# 3     09/01/2020                     Mamaearth                  E-commerce
# 4     02/01/2020  https://www.wealthbucket.in/                     FinTech
# 5     02/01/2020                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2868  29/04/2015                       Icertis   Cloud Enterprise Software
# 2869  29/04/2015                        Tracxn  Startup Analytics platform
# 2871  29/04/2015                      Tradelab  Financial Markets Software
# 2872  29/04/2015                        PiQube   Hiring Analytics platform
# 2873  29/04/2015               Travel Triangle   Online Travel Marketplace
#
#                                 subvertical       city  \
# ...

# %%
df.isna().sum()
# Out:
# date                   0
# startup_name           0
# industry_vertical    171
# subvertical          171
# city                 180
# investor              24
# investment_type        4
# amount               960
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3044 non-null   object
#  1   startup_name       3044 non-null   object
#  2   industry_vertical  2873 non-null   object
#  3   subvertical        2873 non-null   object
#  4   city               2864 non-null   object
#  5   investor           3020 non-null   object
#  6   investment_type    3040 non-null   object
#  7   amount             2084 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
df[df['amount'] ==0 ].sum()
# Out:
# date                 0
# startup_name         0
# industry_vertical    0
# subvertical          0
# city                 0
# investor             0
# investment_type      0
# amount               0
# dtype: object

# %%
df['amount'] = df['amount'].fillna(0.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3044 non-null   object
#  1   startup_name       3044 non-null   object
#  2   industry_vertical  2873 non-null   object
#  3   subvertical        2873 non-null   object
#  4   city               2864 non-null   object
#  5   investor           3020 non-null   object
#  6   investment_type    3040 non-null   object
#  7   amount             3044 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
df['amount'].str.isdigit()
# Out:
# srno
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 3040    False
# 3041    False
# 3042    False
# 3043      NaN
# 3044    False
# Name: amount, Length: 3044, dtype: object

# %%
df.loc[3043:3044]
# Out:
#             date      startup_name industry_vertical subvertical city  \
# srno
# 3043  30/01/2015         Simplotel               NaN         NaN  NaN
# 3044  31/01/2015  couponmachine.in               NaN         NaN  NaN
#
#                                investor investment_type    amount
# srno
# 3043                         MakeMyTrip  Private Equity       0.0
# 3044  UK based Group of Angel Investors    Seed Funding  1,40,000

# %%
df['amount'].value_counts()
# Out:
# amount
# 0.0                     960
# 10,00,000               165
# 5,00,000                108
# 20,00,000                69
# 50,00,000                66
#                        ...
# 7,90,000                  1
# \\xc2\\xa010,000,000      1
# \\xc2\\xa05,000,000       1
# \\xc2\\xa019,350,000      1
# \\xc2\\xa0685,000         1
# Name: count, Length: 472, dtype: int64

# %%
df['amount'] = df['amount'].str.replace(',','')
str1 = []
for i in df['amount']:
    try:
        num1 = pd.to_numeric(i)
    except:
        str1.append(i)
str1
# Out:
# ['undisclosed',
#  'unknown',
#  'Undisclosed',
#  'undisclosed',
#  'undisclosed',
#  '14342000+',
#  'Undisclosed',
#  'Undisclosed',
#  '\\\\xc2\\\\xa020000000',
#  '\\\\xc2\\\\xa016200000',
#  '\\\\xc2\\\\xa0N/A',
#  '\\\\xc2\\\\xa0N/A',
#  '\\\\xc2\\\\xa0600000',
#  '\\\\xc2\\\\xa0685000',
#  '\\\\xc2\\\\xa019350000',
#  '\\\\xc2\\\\xa05000000',
#  '\\\\xc2\\\\xa010000000',
#  '\\\\xc2\\\\xa0N/A',
#  '\\\\xc2\\\\xa0N/A']

# %%
rep_dict = {'\\\\xc2\\\\xa019350000':'19350000',
            '\\\\xc2\\\\xa0685000':'685000',
            'undisclosed':'0.0',
            'unknown':'0.0',
            'Undisclosed':'0.0',
            'Undisclosed':'0.0',
            '14342000+':'14342000',
            '\\\\xc2\\\\xa020000000':'20000000',
            '\\\\xc2\\\\xa016200000':'16200000',
            '\\\\xc2\\\\xa0N/A':'0.0',
            '\\\\xc2\\\\xa0N/A':'0.0',
            '\\\\xc2\\\\xa0600000':'600000',
            '\\\\xc2\\\\xa0685000':'685000',
            '\\\\xc2\\\\xa019350000':'19350000',
            '\\\\xc2\\\\xa05000000':'5000000',
            '\\\\xc2\\\\xa010000000':'10000000',
            '\\\\xc2\\\\xa0N/A':'0.0',
            '\\\\xc2\\\\xa0N/A':'0.0',
            ',':"",
            '+':''
            }
for i,j in rep_dict.items():
   df['amount'] = df['amount'].str.replace(i,j)
df['amount']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 22>()
#       1 rep_dict = {'\\\\xc2\\\\xa019350000':'19350000',
#       2             '\\\\xc2\\\\xa0685000':'685000',
#       3             'undisclosed':'0.0',
#    (...)
#      20             '+':''
#      21             }
#      22 for i,j in rep_dict.items():
# ---> 23    df['amount'] = df['amount'].str.replace(i,j)
#      24 df['amount']
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...

# %%
df['amount'] = df['amount'].str.replace(',','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 df['amount'] = df['amount'].str.replace(',','')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
df['amount'] = df['amount'].astype(float)

# %%
str1 = []
for i in df['amount']:
    try:
        num1 = pd.to_numeric(i)
    except:
        str1.append(i)
str1
# Out:
# []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3044 non-null   object
#  1   startup_name       3044 non-null   object
#  2   industry_vertical  2873 non-null   object
#  3   subvertical        2873 non-null   object
#  4   city               2864 non-null   object
#  5   investor           3020 non-null   object
#  6   investment_type    3040 non-null   object
#  7   amount             2084 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 278.6+ KB

# %%
pd.to_datetime(df['date'],format='%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 pd.to_datetime(df['date'],format='%d/%m/%Y')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# ...

# %%
date1 = []
for i in df['date']:
    try:
        date2 = pd.to_datetime(i,format='%d/%m/%Y')
    except:
        date1.append(i)
date1
# Out:
# ['01/07/015',
#  '\\\\xc2\\\\xa010/7/2015',
#  '12/05.2015',
#  '12/05.2015',
#  '13/04.2015',
#  '15/01.2015',
#  '22/01//2015']

# %%
rep_dict2 = {'05/072018':'05/07/2018',
             '\\\\xc2\\\\xa010/7/2015':'10/7/2015',
             '12/05.2015':'12/05/2015',
          '13/04.2015':'13/04/2015',
             '15/01.2015':'15/01/2015',
             '22/01//2015':'22/01/2015',
             '01/07/015':'01/07/2015'
            }
for i,j in rep_dict2.items():
    df['date'] = df['date'].str.replace(i,j)

# %%
date1 = []
for i in df['date']:
    try:
        date2 = pd.to_datetime(i,format='%d/%m/%Y')
    except:
        date1.append(i)
date1
# Out:
# []

# %%
df['date'] = pd.to_datetime(df['date'],format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3044 non-null   datetime64[ns]
#  1   startup_name       3044 non-null   object
#  2   industry_vertical  2873 non-null   object
#  3   subvertical        2873 non-null   object
#  4   city               2864 non-null   object
#  5   investor           3020 non-null   object
#  6   investment_type    3040 non-null   object
#  7   amount             2084 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 278.6+ KB
